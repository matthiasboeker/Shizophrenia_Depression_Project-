# %%
import numpy as np
import os
import pandas as pd 
import matplotlib.pyplot as plt

os.chdir('/Users/matthiasboeker/Desktop/Master_Thesis/Schizophrenia_Depression_Project')
from Modules.support_functions import *

# %%
#Import Schizophrenia data
os.chdir('/Users/matthiasboeker/Desktop/Master_Thesis/Schizophrenia_Depression_Project/Data/psykose/patient')
files = os.listdir()
files.sort(key=natural_keys)
shizophrenia_p = list()
for i in range(0,len(files)):
    if files[i].endswith('.csv'):
        shizophrenia_p.append(pd.read_csv(files[i]))
    
os.chdir('/Users/matthiasboeker/Desktop/Master_Thesis/Schizophrenia_Depression_Project/Data/psykose/control')
files = os.listdir()
files.sort(key=natural_keys)
shizophrenia_c = list()
for i in range(0,len(files)):
    if files[i].endswith('.csv'):
        shizophrenia_c.append(pd.read_csv(files[i]))
#Import demographics on Schizophrenia patients
os.chdir('/Users/matthiasboeker/Desktop/Master_Thesis/Schizophrenia_Depression_Project/Data/psykose')
patients_info = pd.read_csv('patients_info.csv')
#Import demographics on control group 
control_info = pd.read_csv('scores.csv')

# %% [markdown]
# ## Moving Average Smoothing

# %%
param= 30
filtered = shizophrenia_p[5]['activity'].rolling(window=param).mean()
smoothed = filtered.iloc[param:]
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
ax.plot(smoothed)
ax.set_xlabel('Activity')
ax.set_ylabel('Time')
# Out:
# Text(0,0.5,'Time')

# %%
print(len(smoothed))
print(len(smoothed.loc[smoothed == 0]))
# Out:
# 21855
# 1728

# %% [markdown]
# ## Gaussian Filter

# %%
from scipy.ndimage import gaussian_filter
gauss_filt = gaussian_filter(shizophrenia_p[5]['activity'], sigma=50)
print(len(gauss_filt))
# Out:
# 21885

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
ax.plot(shizophrenia_p[5]['activity'])
ax.plot(gauss_filt)

# %% [markdown]
# ## Fourier Transformation

# %%
from scipy.fft import fft, ifft
from scipy.fft import fftfreq

trans_fft = fft(shizophrenia_p[5]['activity'])
trans_psd = np.log(np.abs(trans_fft))
freq = fftfreq(len(shizophrenia_p[5]['activity']),(1. / 32))
i = freq > 0

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
ax.plot(freq[i], 10 * np.log10(trans_psd[i])**2)
ax.set_xlim(0, 5)
ax.set_xlabel('Frequency (1/minute)')
ax.set_ylabel('PSD (dB)')
# Out:
# Text(0,0.5,'PSD (dB)')

# %%
max_peak = freq[np.argmax( trans_psd[i])]
print(max_peak)
# Out:
# 0.020470641992232124

# %%
trans_fft_bis = trans_fft.copy()
trans_fft_bis[np.abs(freq) > max_peak+0.03] = 0

# %%
back = pd.Series(np.real(ifft(trans_fft_bis)))
fig, ax = plt.subplots(1, 1, figsize=(8, 4))
ax.plot(shizophrenia_p[5]['activity'])
ax.plot(back)

# %% [markdown]
# ## Analysing derivative of FFT

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3, 1, figsize=(10, 6))
ax1.plot(back)
ax1.set_title('FFT')
ax2.plot(np.gradient(back))
ax2.set_title('Gradient FFT')
ax3.plot(np.gradient(np.gradient(back)))
ax3.set_title('Second Gradient FFT')

# %% [markdown]
# ### Extracting the extreme values

# %%
deriv = np.gradient(back)

asign = np.sign(deriv)
signchanges = pd.Series(((np.roll(asign, 1) - asign) != 0).astype(int))
extreme_val = signchanges.loc[signchanges==1].index

# %%
deriv2 = np.gradient(deriv)
asign2 = np.sign(deriv2)
signchanges2 = pd.Series(((np.roll(asign2, 1) - asign2) != 0).astype(int))
extreme_val2 = signchanges2.loc[signchanges2==1].index

# %% [markdown]
# ## Use Gaussian Mixture model of fft to identify hidden states

# %%
import sklearn.mixture as mix

n_components = range(1, 10)
models = [mix.GaussianMixture(n, covariance_type='full', random_state=0)
          for n in n_components]
aics_g = [model.fit(np.array(gauss_filt).reshape(-1, 1)).aic(np.array(gauss_filt).reshape(-1, 1)) for model in models]
bics_g = [model.fit(np.array(gauss_filt).reshape(-1, 1)).bic(np.array(gauss_filt).reshape(-1, 1)) for model in models]
aics_fft = [model.fit(np.array(back).reshape(-1, 1)).aic(np.array(back).reshape(-1, 1)) for model in models]
bics_fft = [model.fit(np.array(back).reshape(-1, 1)).bic(np.array(back).reshape(-1, 1)) for model in models]
plt.plot(n_components, aics_g, label='AIC Gaussian Filter')
plt.plot(n_components, bics_g, label = 'BIC Gaussian Filter')
plt.plot(n_components, aics_fft, label='AIC FFT')
plt.plot(n_components, bics_fft, label = 'BIC FFT')
plt.legend()
print('Gaussian Filter has a lower AIC and BIC ')
# Out:
# Gaussian Filter has a lower AIC and BIC

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(tt)
plot_pacf(tt)

# %% [markdown]
# ### Gaussian Mixture Model of the Gaussian filtered Series

# %%
# remodel the time series to matrix 
tt = shizophrenia_p[5]['activity']
gt = pd.Series(gauss_filt)
# How to determine a ? 
a = 5
binn = list()
for i in range(0,len(gt)-a):
    row = gt.iloc[i:i+a]
    binn.append(row)
matrix = np.array(binn)

# %%
import sklearn.mixture as mix

n_components = range(1, 10)
models = [mix.GaussianMixture(n, covariance_type='full', random_state=0)
          for n in n_components]
aics_m = [model.fit(matrix).aic(matrix) for model in models]
bics_m = [model.fit(matrix).bic(matrix) for model in models]
aics_s = [model.fit(np.array(gauss_filt).reshape(-1, 1)).aic(np.array(gauss_filt).reshape(-1, 1)) for model in models]
bics_s = [model.fit(np.array(gauss_filt).reshape(-1, 1)).bic(np.array(gauss_filt).reshape(-1, 1)) for model in models]
plt.plot(n_components, aics_m, label='AIC matrix')
plt.plot(n_components, bics_m, label = 'BIC matrix')
plt.plot(n_components, aics_s, label='AIC series')
plt.plot(n_components, bics_s, label = 'BIC series')
plt.legend()
#print('Gaussian Filter has a lower AIC and BIC ')

# %%
import sklearn.mixture as mix
model = mix.GaussianMixture(n_components=2, 
                            covariance_type="spherical", 
                            n_init=100, 
                            random_state=7).fit(np.array(gauss_filt).reshape(-1, 1))
print(model.converged_)
hidden_states = model.predict(np.array(gauss_filt).reshape(-1, 1))
state_prob = model.predict_proba(np.array(gauss_filt).reshape(-1, 1))
# Out:
# True

# %%
fig = plt.figure(figsize=(8,5))
color = ['darkorange' if x>1 else 'green' if x==1 else  'navy'  for x in hidden_states[:2500]]
for x, l, c in zip(tt.index[:2500], tt[:2500], color):
    plt.scatter(x, l, alpha=0.8, c=c,marker='.', linewidths=0.01) 
    plt.title('Features')
plt.scatter(gt[:2500].index, gt[:2500], c='red', marker='.', linewidths=0.01, label = 'Gaussian Filtered Series')
plt.plot(np.max(state_prob[:2500]*1000, axis=1), label = 'State probabilty *1000')
plt.legend(loc='upper right')

# %%
import sklearn.mixture as mix
model = mix.GaussianMixture(n_components=2, 
                            covariance_type="spherical", 
                            n_init=100, 
                            random_state=7).fit(matrix)
print(model.converged_)
hidden_states = model.predict(matrix)
state_prob = model.predict_proba(matrix)
# Out:
# True

# %%
fig = plt.figure(figsize=(8,5))
color = ['darkorange' if x>1 else 'green' if x==1 else  'navy'  for x in hidden_states[:2500]]
for x, l, c in zip(tt.index[:2500], tt[:2500], color):
    plt.scatter(x, l, alpha=0.8, c=c,marker='.', linewidths=0.01) 
    plt.title('Features')
plt.scatter(gt[:2500].index, gt[:2500], c='red', marker='.', linewidths=0.01, label = 'Gaussian Filtered Series')
plt.plot(np.max(state_prob[:2500]*1000, axis=1), label = 'State probabilty *1000')
plt.legend(loc='upper right')

# %%
print("Means and vars of each hidden state")
for i in range(model.n_components):
    print("{0}th hidden state".format(i))
    print("mean = ", model.means_[i])
    print("var = ", model.covariances_[i])
# Out:
# Means and vars of each hidden state
# 0th hidden state
# mean =  [14.31572893]
# var =  [[91.93486337]]
# 1th hidden state
# mean =  [137.57192975]
# var =  [[2401.90528171]]
